# %% [markdown]
# # TP1: análisis exploratorio

# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %%
raw_eventos = pd.read_csv('data/events.csv')
# Out:
# /home/vasectomio/.virtualenvs/datos/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_eventos.timestamp = raw_eventos.timestamp.map(pd.Timestamp)

# %%
raw_eventos.event.value_counts().plot(title='Tipos de eventos',kind='barh',logx=True)

# %%
print("distribución de eventos en el tiempo")
raw_eventos.timestamp.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2ab7f4454921> in <module>()
# ----> 1 raw_eventos.timestamp.hist(title='distribucion de los eventos en el tiempo')
#
# ~/.virtualenvs/datos/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2479         values = self.dropna().values
#    2480
# -> 2481         ax.hist(values, bins=bins, **kwds)
#    2482         ax.grid(grid)
#    2483         axes = np.array([ax])
#
# ~/.virtualenvs/datos/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
# ...

# %%
# Cuantos 'skus' distintos hay
print( "hay {} eventos y {} eventos distintos".format(len(raw_eventos.skus.dropna().values), len(raw_eventos.skus.unique())))
# Out:
# hay 221699 eventos y 35311 eventos distintos
