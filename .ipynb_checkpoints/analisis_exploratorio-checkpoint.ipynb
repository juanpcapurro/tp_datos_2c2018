# %% [markdown]
# # TP1: análisis exploratorio

# %%
import pandas as pd
import numpy as np

# %%
raw_eventos = pd.read_csv('data/events.csv')

# %%
raw_eventos.event.value_counts().plot(title='Tipos de eventos',kind='bar')
